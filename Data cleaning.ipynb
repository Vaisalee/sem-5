# %%
import pandas as pd

# %%
file=pd.read_csv("Dress_name.csv")

# %%
file
# Out:
#     Unnamed: 0 price                                               name  \
# 0            0  ₹325  <span class="css-1jxf684 r-op4f77 r-1et8rh5 r-...
# 1            1  ₹326  <span class="css-1jxf684 r-op4f77 r-1et8rh5 r-...
# 2            2  ₹244  <span class="css-1jxf684 r-op4f77 r-1et8rh5 r-...
# 3            3  ₹259  <span class="css-1jxf684 r-op4f77 r-1et8rh5 r-...
# 4            4  ₹279  <span class="css-1jxf684 r-op4f77 r-1et8rh5 r-...
# 5            5  ₹299  <span class="css-1jxf684 r-op4f77 r-1et8rh5 r-...
# 6            6  ₹340  <span class="css-1jxf684 r-op4f77 r-1et8rh5 r-...
# 7            7  ₹299  <span class="css-1jxf684 r-op4f77 r-1et8rh5 r-...
# 8            8  ₹319  <span class="css-1jxf684 r-op4f77 r-1et8rh5 r-...
# 9            9  ₹299  <span class="css-1jxf684 r-op4f77 r-1et8rh5 r-...
# 10          10  ₹373  <span class="css-1jxf684 r-op4f77 r-1et8rh5 r-...
# 11          11  ₹255  <span class="css-1jxf684 r-op4f77 r-1et8rh5 r-...
# ...

# %%
file.drop("Unnamed: 0",axis=1)
# Out:
#    price                                               name  \
# 0   ₹325  <span class="css-1jxf684 r-op4f77 r-1et8rh5 r-...
# 1   ₹326  <span class="css-1jxf684 r-op4f77 r-1et8rh5 r-...
# 2   ₹244  <span class="css-1jxf684 r-op4f77 r-1et8rh5 r-...
# 3   ₹259  <span class="css-1jxf684 r-op4f77 r-1et8rh5 r-...
# 4   ₹279  <span class="css-1jxf684 r-op4f77 r-1et8rh5 r-...
# 5   ₹299  <span class="css-1jxf684 r-op4f77 r-1et8rh5 r-...
# 6   ₹340  <span class="css-1jxf684 r-op4f77 r-1et8rh5 r-...
# 7   ₹299  <span class="css-1jxf684 r-op4f77 r-1et8rh5 r-...
# 8   ₹319  <span class="css-1jxf684 r-op4f77 r-1et8rh5 r-...
# 9   ₹299  <span class="css-1jxf684 r-op4f77 r-1et8rh5 r-...
# 10  ₹373  <span class="css-1jxf684 r-op4f77 r-1et8rh5 r-...
# 11  ₹255  <span class="css-1jxf684 r-op4f77 r-1et8rh5 r-...
# 12  ₹355  <span class="css-1jxf684 r-op4f77 r-1et8rh5 r-...
# 13  ₹210  <span class="css-1jxf684 r-op4f77 r-1et8rh5 r-...
# 14  ₹290  <span class="css-1jxf684 r-op4f77 r-1et8rh5 r-...
# ...

# %%
file["name"]=file["name"].str.strip('<span class=""css-1jxf684 r-op4f77 r-1et8rh5 r-1b43r93 r-14yzgew r-zl2h9q r-1udh08x"">,</span>').astype(str)

# %%
file
# Out:
#     Unnamed: 0 price                                               name  \
# 0            0  ₹325                                   Sneakers For Wom
# 1            1  ₹326                                   Sneakers For Wom
# 2            2  ₹244  Doctor Walk|Comfort|Trendy|Lightweight|Ortho|H...
# 3            3  ₹259  Sports outdoor walking Running ,gym and loafer...
# 4            4  ₹279                                   Outdoors For Wom
# 5            5  ₹299                              Walking Shoes For Wom
# 6            6  ₹340                                   Sneakers For Wom
# 7            7  ₹299                              Walking Shoes For Wom
# 8            8  ₹319  Stylish &amp; Comfortable Casual Men's Shoes -...
# 9            9  ₹299                              Running Shoes For Wom
# 10          10  ₹373                                   Sneakers For Wom
# 11          11  ₹255  Kcandy Running,Walking,Training,Sports Shoes,C...
# ...

# %%
file.drop("Unnamed: 0",axis=1)
# Out:
#    price                                               name  \
# 0   ₹325                                   Sneakers For Wom
# 1   ₹326                                   Sneakers For Wom
# 2   ₹244  Doctor Walk|Comfort|Trendy|Lightweight|Ortho|H...
# 3   ₹259  Sports outdoor walking Running ,gym and loafer...
# 4   ₹279                                   Outdoors For Wom
# 5   ₹299                              Walking Shoes For Wom
# 6   ₹340                                   Sneakers For Wom
# 7   ₹299                              Walking Shoes For Wom
# 8   ₹319  Stylish &amp; Comfortable Casual Men's Shoes -...
# 9   ₹299                              Running Shoes For Wom
# 10  ₹373                                   Sneakers For Wom
# 11  ₹255  Kcandy Running,Walking,Training,Sports Shoes,C...
# 12  ₹355                           Stylish Sneakers For Wom
# 13  ₹210  Girls Stylish Designer Jaipuri Rajasthani Moja...
# 14  ₹290                                   Sneakers For Wom
# ...

# %%
file["offer"]=file["offer"].str.strip('<div class=""css-146c3p1 r-183gjk9 r-1vgyyaa r-1enofrn r-1rsjblm r-11wrixw"" dir=""auto"">,% off</div>').astype(str)

# %%
file
# Out:
#     Unnamed: 0 price                                               name offer
# 0            0  ₹325                                   Sneakers For Wom     7
# 1            1  ₹326                                   Sneakers For Wom     7
# 2            2  ₹244  Doctor Walk|Comfort|Trendy|Lightweight|Ortho|H...    75
# 3            3  ₹259  Sports outdoor walking Running ,gym and loafer...     7
# 4            4  ₹279                                   Outdoors For Wom    72
# 5            5  ₹299                              Walking Shoes For Wom    70
# 6            6  ₹340                                   Sneakers For Wom     5
# 7            7  ₹299                              Walking Shoes For Wom    70
# 8            8  ₹319  Stylish &amp; Comfortable Casual Men's Shoes -...
# 9            9  ₹299                              Running Shoes For Wom    70
# 10          10  ₹373                                   Sneakers For Wom     2
# ...

# %% [markdown]
# ## CATAGORICAL DATA

# %%
Salary_Data=pd.DataFrame({"Salary":[10000,20000,30000,40000,50000],"Range":['low','low','mid','mid','high']})

# %%
Salary_Data
# Out:
#    Salary Range
# 0   10000   low
# 1   20000   low
# 2   30000   mid
# 3   40000   mid
# 4   50000  high

# %%
code=Salary_Data.Range.map({'low':3,'mid':2,'high':1})

# %%
code
# Out:
# 0    3
# 1    3
# 2    2
# 3    2
# 4    1
# Name: Range, dtype: int64

# %%
publish=pd.DataFrame(Salary_Data['Salary'],columns=['Salary'])

# %%
publish["code"]=code

# %%
publish
# Out:
#    Salary  code
# 0   10000     3
# 1   20000     3
# 2   30000     2
# 3   40000     2
# 4   50000     1

# %%
Test_Data=
