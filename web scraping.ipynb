# %% [markdown]
# ## WEB SCRAPPING

# %%
pip install bs4
# Out:
# ...
#   Obtaining dependency information for bs4 from https://files.pythonhosted.org/packages/51/bb/bf7aab772a159614954d84aa832c129624ba6c32faa559dfb200a534e50b/bs4-0.0.2-py2.py3-none-any.whl.metadata
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
import pandas as pd

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
url="https://www.shopsy.in/footwear-online/pr?p%5B%5D=facets.ideal_for%255B%255D%3DWomen"

# %%
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
url2="https://www.shopsy.in/footwear-online/pr?p%5B%5D=facets.ideal_for%255B%255D%3DWomen"

# %%
response=requests.get(url2)

# %%
response
# Out:
# <Response [200]>

# %%
Back_code=BeautifulSoup(response.text)

# %%
Back_code
# Out:
# <!DOCTYPE html>
# ...

# %%
Dress_name=Back_code.select(".r-13hce6t")

# %%
Dress_name
# Out:
# [<div class="css-175oi2r r-13hce6t r-1d4mawv"><div class="css-175oi2r"><div class="css-175oi2r"><div class="css-175oi2r" style="position:absolute;top:0px;bottom:0px;left:0px;right:0px"></div><div class="css-175oi2r r-1habvwh r-eqz5dr r-1h0z5md" style="width:275.03px"><div class="css-175oi2r r-1w6e6rj r-1u7ml5x r-1udh08x" style="width:275.03px"><div class="css-175oi2r r-1awozwy r-1777fci r-knv0ih"><div class="css-175oi2r r-1yav64w r-z2wwpe r-rs99b7 r-1udh08x"><div class="css-175oi2r" style="width:273.03px;height:282px"><img alt="Image Placeholder" class="next-img" data-nimg="1" decoding="async" fetchpriority="auto" height="282" loading="lazy" src="https://rukminim2.flixcart.com/image/640/661/xif0q/shoe/b/b/3/7-hpltpepsi1gry-7-okaywalk-gry-original-imaggyxmx3w4pb5g.jpeg?q=60" srcset="https://rukminim2.flixcart.com/image/440/454/xif0q/shoe/b/b/3/7-hpltpepsi1gry-7-okaywalk-gry-original-imaggyxmx3w4pb5g.jpeg?q=60 1x, https://rukminim2.flixcart.com/image/640/661/xif0q/shoe/b/b/3/7-hpltpeps
# ...

# %%
Price=Back_code.select(".r-1rsjblm.r-13hce6t")

# %%
Price
# Out:
# [<div class="css-146c3p1 r-cqee49 r-1vgyyaa r-ubezar r-1rsjblm r-13hce6t" dir="auto">₹384</div>,
#  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-ubezar r-1rsjblm r-13hce6t" dir="auto">₹344</div>,
#  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-ubezar r-1rsjblm r-13hce6t" dir="auto">₹364</div>,
#  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-ubezar r-1rsjblm r-13hce6t" dir="auto">₹364</div>,
#  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-ubezar r-1rsjblm r-13hce6t" dir="auto">₹361</div>,
#  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-ubezar r-1rsjblm r-13hce6t" dir="auto">₹284</div>,
#  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-ubezar r-1rsjblm r-13hce6t" dir="auto">₹314</div>,
#  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-ubezar r-1rsjblm r-13hce6t" dir="auto">₹284</div>,
#  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-ubezar r-1rsjblm r-13hce6t" dir="auto">₹284</div>,
#  <div class="css-146c3p1 r-cqee49 r-1vgyyaa r-ubezar r-1rsjblm r-13hce6t" dir="auto">₹384</div>,
# ...

# %%
data_frame_price=pd.DataFrame(Price,columns=["price"])

# %%
data_frame_price
# Out:
#    price
# 0   ₹384
# 1   ₹344
# 2   ₹364
# 3   ₹364
# 4   ₹361
# 5   ₹284
# 6   ₹314
# 7   ₹284
# 8   ₹284
# 9   ₹384
# 10  ₹284
# 11  ₹314
# 12  ₹384
# 13  ₹250
# 14  ₹264
# 15  ₹295
# 16  ₹384
# 17  ₹314
# 18  ₹364
# 19  ₹272
# 20  ₹404
# 21  ₹434
# 22  ₹280
# 23  ₹284
# 24  ₹384
# 25  ₹304
# 26  ₹284
# 27  ₹384
# 28  ₹284
# 29  ₹214
# 30  ₹384
# 31  ₹234
# 32  ₹384
# 33  ₹184
# 34  ₹284
# 35  ₹384
# 36  ₹284
# 37  ₹484
# 38  ₹384
# 39  ₹284

# %%
data_frame_name=pd.DataFrame(Dress_name,columns=["name"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 data_frame_name=pd.DataFrame(Dress_name,columns=["name"])
#
# File ~\anaconda3\envs\vaisalee\Lib\site-packages\pandas\core\frame.py:867, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     859         mgr = arrays_to_mgr(
#     860             arrays,
#     861             columns,
#    (...)
#     864             typ=manager,
#     865         )
#     866     else:
# --> 867         mgr = ndarray_to_mgr(
#     868             data,
#     869             index,
#     870             columns,
#     871             dtype=dtype,
#     872             copy=copy,
#     873             typ=manager,
#     874         )
#     875 else:
#     876     mgr = dict_to_mgr(
#     877         {},
#     878         index,
#    (...)
#     881         typ=manager,
#     882     )
#
# ...

# %%
data_frame_name
# Out:
#    price
# 0   ₹384
# 1   ₹344
# 2   ₹364
# 3   ₹364
# 4   ₹361
# 5   ₹284
# 6   ₹314
# 7   ₹284
# 8   ₹284
# 9   ₹384
# 10  ₹284
# 11  ₹314
# 12  ₹384
# 13  ₹250
# 14  ₹264
# 15  ₹295
# 16  ₹384
# 17  ₹314
# 18  ₹364
# 19  ₹272
# 20  ₹404
# 21  ₹434
# 22  ₹280
# 23  ₹284
# 24  ₹384
# 25  ₹304
# 26  ₹284
# 27  ₹384
# 28  ₹284
# 29  ₹214
# 30  ₹384
# 31  ₹234
# 32  ₹384
# 33  ₹184
# 34  ₹284
# 35  ₹384
# 36  ₹284
# 37  ₹484
# 38  ₹384
# 39  ₹284
