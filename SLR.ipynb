# %% [markdown]
# # Machine Learning-Supervised Learning

# %% [markdown]
# 1.Regression
# 2.Classification

# %% [markdown]
# # Importing library

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Importing Data set

# %%
my_data=pd.read_csv("Admission_Predict.csv")

# %%
my_data2=my_data.drop(['Serial No.','GRE Score','TOEFL Score','University Rating','SOP','LOR ','Research'],axis=1)

# %%
my_data2
# Out:
#      CGPA  Chance of Admit
# 0    9.65              0.92
# 1    8.87              0.76
# 2    8.00              0.72
# 3    8.67              0.80
# 4    8.21              0.65
# ..    ...               ...
# 395  9.04              0.82
# 396  9.11              0.84
# 397  9.45              0.91
# 398  8.78              0.67
# 399  9.66              0.95
#
# [400 rows x 2 columns]

# %%
x=my_data2.iloc[:,0]

# %%
x
# Out:
# 0      9.65
# 1      8.87
# 2      8.00
# 3      8.67
# 4      8.21
#        ...
# 395    9.04
# 396    9.11
# 397    9.45
# 398    8.78
# 399    9.66
# Name: CGPA, Length: 400, dtype: float64

# %%
x=my_data2.iloc[:,0].values.reshape(-1,1)
y=my_data2.iloc[:,1].values.reshape(-1,1)

# %% [markdown]
# # Splitting the dataset

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\admin\anaconda3\envs\vaisalee\lib\site-packages (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in c:\users\admin\anaconda3\envs\vaisalee\lib\site-packages (from scikit-learn) (1.26.0)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\admin\anaconda3\envs\vaisalee\lib\site-packages (from scikit-learn) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\admin\anaconda3\envs\vaisalee\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\admin\anaconda3\envs\vaisalee\lib\site-packages (from scikit-learn) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
# array([[8.79],
#        [8.7 ],
#        [7.7 ],
#        [9.18],
#        [8.  ],
#        [9.01],
#        [8.36],
#        [8.54],
#        [9.04],
#        [9.14],
#        [8.84],
#        [9.68],
#        [7.4 ],
#        [8.  ],
#        [9.16],
#        [8.48],
#        [8.77],
#        [8.24],
#        [8.76],
#        [8.9 ],
#        [8.57],
#        [8.5 ],
#        [9.  ],
#        [7.9 ],
#        [8.9 ],
#        [8.46],
#        [9.5 ],
#        [8.04],
#        [8.75],
#        [8.57],
#        [8.  ],
#        [8.76],
#        [8.67],
#        [8.4 ],
#        [9.17],
#        [9.26],
#        [9.34],
#        [8.4 ],
#        [8.37],
#        [8.13],
#        [8.03],
#        [8.45],
#        [9.31],
#        [8.27],
#        [7.56],
#        [9.44],
#        [9.5 ],
#        [8.54],
#        [8.27],
#        [7.8 ],
#        [9.43],
#        [8.76],
#        [9.02],
#        [7.68],
#        [8.97],
#        [8.12],
#        [9.18],
#        [8.76],
#        [8.02],
#        [8.  ],
#        [9.01],
#        [8.68],
#        [8.1 ],
#        [8.45],
#        [8.79],
#        [8.47],
#        [7.64],
#        [9.02],
#        [9.23],
#        [8.62],
#        [8.66],
#        [9.56],
#        [9.  ],
#        [8.34],
#        [9.36],
#        [8.45],
#        [8.96],
#        [9.32],
#        [8.43],
#        [8.65],
#        [9.11],
#        [8.78],
#        [9.6 ],
#        [7.65],
#        [8.5 ],
#        [9.8 ],
#        [8.33],
#        [8.96],
#        [8.66],
#        [8.2 ],
#        [8.27],
#        [8.79],
#        [8.54],
#        [8.65],
#        [8.65],
#        [9.08],
#        [9.38],
#        [9.3 ],
#        [8.5 ],
#        [9.11],
#        [8.23],
#        [9.04],
#        [8.16],
#        [8.67],
#        [8.75],
#        [9.06],
#        [7.3 ],
#        [8.42],
#        [8.64],
#        [7.86],
#        [7.9 ],
#        [8.77],
#        [8.06],
#        [7.5 ],
#        [8.  ],
#        [9.13],
#        [8.34],
#        [9.66],
#        [7.43],
#        [8.56],
#        [9.08],
#        [9.17],
#        [8.42],
#        [7.95],
#        [8.49],
#        [9.  ],
#        [7.89],
#        [9.2 ],
#        [8.54],
#        [9.12],
#        [8.64],
#        [9.8 ],
#        [8.21],
#        [9.4 ],
#        [8.15],
#        [9.35],
#        [7.88],
#        [8.68],
#        [8.33],
#        [8.44],
#        [8.26],
#        [8.24],
#        [8.  ],
#        [8.8 ],
#        [9.66],
#        [7.36],
#        [8.83],
#        [9.23],
#        [9.76],
#        [8.  ],
#        [7.46],
#        [9.78],
#        [9.82],
#        [7.8 ],
#        [8.67],
#        [7.86],
#        [9.05],
#        [7.46],
#        [9.36],
#        [9.08],
#        [9.45],
#        [7.28],
#        [9.12],
#        [9.36],
#        [8.16],
#        [7.66],
#        [8.48],
#        [8.26],
#        [8.26],
#        [9.06],
#        [8.7 ],
#        [8.34],
#        [8.56],
#        [8.64],
#        [7.86],
#        [7.65],
#        [8.07],
#        [9.12],
#        [9.19],
#        [8.69],
#        [8.87],
#        [8.53],
#        [8.5 ],
#        [8.45],
#        [9.1 ],
#        [8.67],
#        [9.45],
#        [8.66],
#        [8.22],
#        [8.32],
#        [8.76],
#        [8.43],
#        [7.64],
#        [7.88],
#        [8.77],
#        [8.02],
#        [8.76],
#        [9.  ],
#        [9.24],
#        [8.42],
#        [8.45],
#        [8.4 ],
#        [9.15],
#        [6.8 ],
#        [8.2 ],
#        [8.22],
#        [8.3 ],
#        [8.12],
#        [8.01],
#        [7.86],
#        [8.12],
#        [8.22],
#        [8.79],
#        [8.2 ],
#        [8.45],
#        [9.76],
#        [9.44],
#        [9.7 ],
#        [9.1 ],
#        [9.65],
#        [8.46],
#        [8.66],
#        [9.24],
#        [8.1 ],
#        [8.12],
#        [8.56],
#        [7.66],
#        [8.03],
#        [7.84],
#        [8.67],
#        [7.98],
#        [9.16],
#        [8.8 ],
#        [8.85],
#        [8.02],
#        [8.73],
#        [8.53],
#        [9.8 ],
#        [9.92],
#        [8.16],
#        [8.65],
#        [7.89],
#        [8.78],
#        [8.36],
#        [8.33],
#        [9.87],
#        [9.45],
#        [9.48],
#        [7.43],
#        [8.34],
#        [7.66],
#        [9.22],
#        [8.17],
#        [8.84],
#        [7.87],
#        [7.6 ],
#        [8.44],
#        [8.64],
#        [8.12],
#        [8.5 ],
#        [8.78],
#        [7.88],
#        [8.01],
#        [8.17],
#        [7.5 ],
#        [8.1 ],
#        [7.34],
#        [9.1 ],
#        [7.65],
#        [7.2 ],
#        [8.8 ],
#        [8.56],
#        [9.28],
#        [8.56],
#        [9.91],
#        [8.3 ],
#        [9.4 ],
#        [8.71],
#        [9.11],
#        [9.62],
#        [9.02],
#        [9.23],
#        [9.11],
#        [9.26],
#        [8.24],
#        [9.04],
#        [8.88],
#        [8.74],
#        [9.11],
#        [8.33],
#        [9.04],
#        [9.04],
#        [8.68],
#        [9.45],
#        [8.54],
#        [9.6 ],
#        [8.97],
#        [9.47],
#        [9.74],
#        [8.97],
#        [7.96],
#        [7.7 ],
#        [9.53],
#        [8.13],
#        [8.14],
#        [9.64],
#        [8.28],
#        [7.97],
#        [8.76],
#        [8.62],
#        [9.14],
#        [8.6 ],
#        [8.44],
#        [8.52],
#        [9.  ],
#        [8.18],
#        [8.94],
#        [7.46],
#        [9.7 ],
#        [9.13]])

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
Ypredict=lm.predict(x_test)

# %%
Ypredict
# Out:
# array([[0.71526369],
#        [0.72367342],
#        [0.75731236],
#        [0.65219067],
#        [0.75100506],
#        [0.61855173],
#        [0.74259533],
#        [0.61644929],
#        [0.8834584 ],
#        [0.896073  ],
#        [0.55547871],
#        [0.86663893],
#        [0.71526369],
#        [0.43984484],
#        [0.82879512],
#        [0.6606004 ],
#        [0.6353712 ],
#        [0.83930729],
#        [0.57440061],
#        [0.74259533],
#        [0.84140972],
#        [0.83720485],
#        [0.69634178],
#        [0.45876675],
#        [0.78043914],
#        [0.60593712],
#        [0.50081543],
#        [0.6606004 ],
#        [0.84771702],
#        [0.65008823],
#        [0.60593712],
#        [0.71316125],
#        [0.73418559],
#        [0.60383469],
#        [0.79095131],
#        [0.74890263],
#        [0.58070792],
#        [0.85612676],
#        [0.6542931 ],
#        [0.94653142],
#        [0.69423935],
#        [0.6542931 ],
#        [0.63957607],
#        [0.78043914],
#        [0.83089755],
#        [0.59752739],
#        [0.5239422 ],
#        [0.67531744],
#        [0.62696146],
#        [0.61224442],
#        [0.69844421],
#        [0.79936104],
#        [0.66480527],
#        [0.82248782],
#        [0.73208316],
#        [0.7657221 ],
#        [0.59752739],
#        [0.68162474],
#        [0.7657221 ],
#        [0.82879512],
#        [0.78674644],
#        [0.52183977],
#        [0.6416785 ],
#        [0.52814707],
#        [0.80356591],
#        [0.85402432],
#        [0.73208316],
#        [0.87925353],
#        [0.78464401],
#        [0.7531075 ],
#        [0.57650305],
#        [0.83510242],
#        [0.85402432],
#        [0.57650305],
#        [0.90448274],
#        [0.63957607],
#        [0.67321501],
#        [0.68793205],
#        [0.92130221],
#        [0.57440061]])

# %%
comparison=pd.DataFrame(x_test,columns=["input data"])

# %%
comparison["AVL_o/p"]=y_test

# %%
comparison["pred_o/p"]=Ypredict

# %%
comparison
# Out:
#     input data  AVL_o/p  pred_o/p
# 0         8.56     0.71  0.715264
# 1         8.60     0.70  0.723673
# 2         8.76     0.79  0.757312
# 3         8.26     0.73  0.652191
# 4         8.73     0.72  0.751005
# ..         ...      ...       ...
# 75        8.20     0.61  0.639576
# 76        8.36     0.69  0.673215
# 77        8.43     0.62  0.687932
# 78        9.54     0.93  0.921302
# 79        7.89     0.43  0.574401
#
# [80 rows x 3 columns]
