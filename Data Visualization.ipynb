# %%
import pandas as pd

# %%
data=pd.read_csv("clean.csv")

# %%
data
# Out:
#      Unnamed: 0 Province/State         Country Date last updated  Confirmed  \
# 0             0       Shanghai  Mainland China         1/21/2020          9
# 1             1         Yunnan  Mainland China         1/21/2020          1
# 2             2        Beijing  Mainland China         1/21/2020         10
# 3             3         Taiwan          Taiwan         1/21/2020          1
# 4             4          Jilin  Mainland China         1/21/2020          0
# ..          ...            ...             ...               ...        ...
# 363         363              0          France   1/26/2020 11:00          3
# 364         364              0       Australia   1/26/2020 11:00          4
# 365         365              0           Nepal   1/26/2020 11:00          1
# 366         366              0        Malaysia   1/26/2020 11:00          4
# 367         367        Ontario          Canada   1/26/2020 11:00          1
#
#      Suspected  Recovered  Deaths
# 0           10          0       0
# 1            0          0       0
# 2            0          0       0
# 3            0          0       0
# 4            1          0       0
# ..         ...        ...     ...
# 363          0          0       0
# 364          0          0       0
# 365          0          0       0
# 366          0          0       0
# 367          0          0       0
#
# [368 rows x 8 columns]

# %%
import matplotlib.pyplot as pt
# %matplotlib inline

# %% [markdown]
# ## SCATTER PLOT

# %%
pt.scatter(data["Confirmed"],data["Deaths"])

# %%
pt.scatter(data["Country"][:50],data["Confirmed"][:50])

# %%
pt.pie(data["Confirmed"][:10],labels=data["Province/State"][:10])
# Out:
# ([<matplotlib.patches.Wedge at 0x242916bd3d0>,
#   <matplotlib.patches.Wedge at 0x242916bf8d0>,
#   <matplotlib.patches.Wedge at 0x242916d4d10>,
#   <matplotlib.patches.Wedge at 0x242916d4ed0>,
#   <matplotlib.patches.Wedge at 0x242916de0d0>,
#   <matplotlib.patches.Wedge at 0x242916ddb10>,
#   <matplotlib.patches.Wedge at 0x242916de9d0>,
#   <matplotlib.patches.Wedge at 0x242916f3e50>,
#   <matplotlib.patches.Wedge at 0x242916e5850>,
#   <matplotlib.patches.Wedge at 0x242916df310>],
#  [Text(0.5111954611888796, 0.9740016429451692, 'Shanghai'),
#   Text(-0.7294349752102589, 0.823361777677352, 'Yunnan'),
#   Text(-0.9740015831181962, -0.5111955751796448, 'Beijing'),
#   Text(0.2632473528277241, -1.0680359690708903, 'Taiwan'),
#   Text(0.3900654979696379, -1.0285178206009358, 'Jilin'),
#   Text(0.6248713371324109, -0.9052821726016441, 'Sichuan'),
#   Text(0.9740017027721292, -0.5111953471981069, 'Tianjin'),
#   Text(1.068036039930965, -0.2632470653370749, 'Ningxia'),
#   Text(1.068036039930965, -0.2632470653370749, 'Anhui'),
#   Text(1.091979782635526, -0.13259017427875117, 'Shandong')])

# %%
pt.bar(data["Province/State"],data["Confirmed"])
# Out:
# <BarContainer object of 368 artists>
